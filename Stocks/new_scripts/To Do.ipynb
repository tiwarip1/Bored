# %% [markdown]
# ## To Do:##
#
# 1. Create functionality to simulate transactions and all fees associated with it, including conversion rates (probably using a class that stores data corresponding to a certain stock symbol)
# 2. Find optimal bollinger bands standard deviation given a stock is oversold using daily data
# 3. Create a good double derivative function for a given moving average and make a function to check how accuate it is to telling of the trendlines of a stock

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import *
# %matplotlib inline

# %%
df = pd.read_csv('../../../stored_data/TSLA.csv')
#df.head()

# %%
std=20*72
df = create_bollinger(df,std)
df.head()
df=df[-1000:]

# %%
plt.plot(df['Close'],'k--',alpha=.4)
plt.plot(df['20 upper'],'r',alpha=.7)
plt.plot(df['20 lower'],'r',alpha=.7)
